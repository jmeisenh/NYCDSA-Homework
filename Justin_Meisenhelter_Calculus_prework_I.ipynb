# %% [markdown]
# For the following x:
# * x = 0
# * x = 1
# * x = 3
# * x = −x
# * x = a
# * x = a + h
#
# Evaluate the function f(x). For the last three values of x, just plug in the value and simplify.
# 1. $f(x) = 5x − 2$
#     + $f(0) = -2$
#     + $f(1) = 4$
#     + $f(3) = 12$
#     + $f(-x) = -5x - 2$
#     + $f(a) = 5a - 2$
#     + $f(a + h) = 5(a + h) -2$
# 2. $f(x) = 4x^2 − 3x + 1$
#     + $f(0) = 1$
#     + $f(1) = 2$
#     + $f(3) = 28$
#     + $f(-x) = 4(-x)^2 + 3x +1$
#     + $f(a) = 4a^2 + 3a +1$
#     + $f(a + h) = a^2 + h^2 + 2ah + 3a + 3h + 1 $
# 3. $f(x) = \frac{2}{x}$
#     + $f(0) = undefined $
#     + $f(1) = 2$
#     + $f(3) = \frac{2}{3}$
#     + $f(-x) = -\frac{2}{x}$
#     + $f(a) =\frac{2}{a} $
#     + $f(a + h) = \frac{2}{(a + h)}$
# 4. $f(x) = |x − 7| + 8$
#     + $f(0) = 15$
#     + $f(1) = 14$
#     + $f(3) = 12$
#     + $f(-x) = |-x - 7| + 8$
#     + $f(a) = |a - 7| + 8$
#     + $f(a + h) =|a + h - 7| + 8 $
# 5. $f(x) = \sqrt{6x + 5}$
#     + $f(0) = \sqrt{5}$
#     + $f(1) = \sqrt{11}$
#     + $f(3) = \sqrt{23}$
#     + $f(-x) = \sqrt{-6x + 5}$
#     + $f(a) = \sqrt{6a + 5}$
#     + $f(a + h) = \sqrt{6a + 6h +5}$
# 6. $f(x) = \frac{x−2}{3x+7}$
#     + $f(0) = -\frac{2}{7}$
#     + $f(1) = -\frac{1}{5}$
#     + $f(3) = \frac{1}{16}$
#     + $f(-x) = \frac{-x-2}{-3x+7}$
#     + $f(a) = \frac{a-2}{3a+7}$
#     + $f(a + h) = \frac{a+h-2}{3a+3h+7}$
# 7. $f(x) = 9$
#     + $f(x)$ is a constant function and will equal $9$ for |$x \in \mathbb{R}, \mathbb{I}$>

# %% [markdown]
# ##### For the following exercises, for each linear equation:
# * Give the slope m and y-intercept b, if any
# * Graph the line
# 1. $y = 2x − 3$
#     + Slope = 2
#     + y-intercept = -3
#
# 2. $y = \frac{1}{7}x + 1$
#     + Slope = $\frac{1}{7}$
#     + y-intercept = 1
#
# 3. $f(x) = −6x$
#     + Slope = -6
#     + y-intercept = 0
#
# 4. $f(x) = −5x + 4$
#     + Slope = -5
#     + y-intercept = 4
#
# 5. $4y + 24 = 0$
#     + simplifies to $y = -6$
#     + Slope = 0
#     + y-intercept = 0 (constant function)
#
# 6. $8x − 4 = 0$
#     + simplifies to $x = \frac{1}{2}$
#     + Slope = undefined
#     + y-intercept = undefined (constant function)
#
# 7. $2x + 3y = 6$
#     + simplifies to $y = -\frac{2x}{3} + 2$
#     + slope = $-\frac{2}{3}$
#     + y-intercept = 2
#
# 8. $6x − 5y + 15 = 0$
#     + simplifies to $y = -\frac{6x}{5} + 3$
#     + y-intercept = 3

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = 2 * x -3

plt.plot(x,y)
plt.title('y = 2x - 3')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-5, 5, 100)
y = (x / 7) -3

plt.plot(x,y)
plt.title('y = (x/7) - 3')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-5, 5, 100)
y = -6 * x

plt.plot(x,y)
plt.title('y = -6x')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-5, 5, 100)
y = -5 * x + 4

plt.plot(x,y)
plt.title('f(x) = -5x + 4')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-5, 5, 100)
y = [ -6 for i in range(100)]

plt.plot(x,y)
plt.title('4y + 24 = 0')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = [0.5 for i in range(100)]
y = np.linspace(-5, 5, 100)

plt.plot(x,y)
plt.title('8x - 4 = 0')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-5, 5, 100)
y = ((-2 * x) / 3) + 2

plt.plot(x,y)
plt.title('2x + 3y = 6')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-5, 5, 100)
y = ((6 * x) / 5) + 3

plt.plot(x,y)
plt.title('6x -5y + 15')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %% [markdown]
# #### Graphing
# For the following exercises, please match the exponential equation to the correct graph.
# + i. $y = 4^{−x}$
#     + corresponds to graph 4
# + ii. $y = 3^{x−1}$
#     + corresponds to graph 3
# + iii. $y = 2^{x+1}$
#     + corresponds to graph 6
# + iv. $y = \frac{1}{2}^x + 2$
#     + corresponds to graph 1
# +  v. $y = −3^{−x}$
#     + corresponds to graph 5
# + vi. $y = 1 − 5^x$
#     + corresponds to graph 2

# %% [markdown]
# #### For the following exercises, sketch the graph of the logarithmic function. Determine the domain, range, and vertical asymptote.
# + 7. $f(x) = 3 + \ln{x}$
#     + $D = x > 0, \in  \mathbb{R}$
#     + $R = y \in \mathbb{R}$
#     + Vertical asymptote: $x= 0$
# + 8. $f(x) = \ln{(x − 1)}$
#     + $D = x > 1, x \in \mathbb{R}$
#     + $R = y \in \mathbb{R}$
#     + vertical asymptote:$x = 1$
# + 9. $f(x) = \ln{(−x)}$
#     + $D = x < 0, \in \mathbb{R}$
#     + $R = y \in \mathbb{R}$
#     + vertical asymptote: $x = 0$
# + 10. $f(x) = 1 − \ln{x}$
#     + $D = x > 0 , \in \mathbb{R}$
#     + $R = y \in \mathbb{R}$
#     + vertical asymptote: $x = 0$
# + 11. $f(x) = \log{x} − 1$
#     + $D = x > 0, \in \mathbb{R}$
#     + $R = y \in \mathbb{R}$
#     + vertical asymptote: $x = 0$
# + 12. $f(x) = \ln{(x + 1)}$
#     + $D = x > -1, \in \mathbb{R}$
#     + $R = y \in \mathbb{R}$
#     + vertical asymptote: $x = -1$

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.linspace(0.001, 10, 100)
y = 3 + np.log(x)

plt.plot(x,y)
plt.title('3 + ln(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(1.0001, 10, 100)
y = np.log(x-1)

plt.plot(x,y)
plt.title('ln(x-1)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-10, -0.0001, 100)
y = np.log(-x)

plt.plot(x,y)
plt.title('ln(-x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(0.0001, 10, 100)
y = 1 - np.log(x)

plt.plot(x,y)
plt.title('1 - ln(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(0.0001, 10, 100)
y = np.log10(x) - 1

plt.plot(x,y)
plt.title('log(x) - 1')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

x = np.linspace(-0.9999, 3, 100)
y = np.log(x+1)

plt.plot(x,y)
plt.title('ln(x+1)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.ylim(-10, 3)
plt.show()

# %% [markdown]
# ### for the function
# <center> $f(x) = (x-1)^2 + 1$ </center>
#
# ### Please sketch the secant line for the following points and evalute the slope.
#
# ### For a = 3, evaluate
#
# + $f(a) = 5$
# + 1. h = −2
#     + $f(a+h) = 1$
#     + $m = \frac{(1 - 5)}{-2} = 2$
#     + $y = mx + b, 5 = 2 * 3 + b, b = -1$
# + 2. h = −1
#     + $f(a+h) = 2$
#     + $m = \frac{(2 - 5)}{-1} = 3$
#     + $y = mx + b, 5 = 3 * 3 + b, b = -4$
# + 3. h = −0.5
#     + $f(a+h) = 3.25$
#     + $m = \frac{(3.25 - 5)}{-0.5} = 3.5$
#     + $y = mx + b, 5 = 3.5 * 3 + b, b = -5.5$

# %%
x = np.linspace(-10, 10, 100)
y = ((x - 1) ** 2) + 1
x1 =  np.linspace(-10, 10, 100)
y1 =  (2 * x) - 1
plt.plot(x,y)
plt.plot(x1,y1)
plt.title('h = -2')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-3, 6)
plt.ylim(-2, 15)
plt.legend(['(x-1)^2 + 1', 'y = 2x -1'])
plt.grid()
plt.show()

x = np.linspace(-10, 10, 100)
y = ((x - 1) ** 2) + 1
x1 =  np.linspace(-10, 10, 100)
y1 =  (3 * x) - 4
plt.plot(x,y)
plt.plot(x1,y1)
plt.title('h = -1')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-2, 6)
plt.ylim(-1, 8)
plt.legend(['(x-1)^2 + 1', 'y = 3x - 4'])
plt.grid()
plt.show()

x = np.linspace(-10, 10, 100)
y = ((x - 1) ** 2) + 1
x1 =  np.linspace(-10, 10, 100)
y1 =  (3.5 * x) - 5.5
plt.plot(x,y)
plt.plot(x1,y1)
plt.title('h = -0.5')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(1, 4)
plt.ylim(0, 8)
plt.legend(['(x-1)^2 + 1', 'y = 3.5x -5.5'])
plt.grid()
plt.show()

# %% [markdown]
# ### For a = 1, evalute
# + $f(a) = 1$
#
# + 4. h = 2
#     + $f(a+h) = 5$
#     + $m = \frac{(5 - 1)}{2} = 2$
#     + $y = mx + b, 1 = 2 * 1 + b, b = -1$
# + 5. h = 1
#     + $f(a+h) = 2$
#     + $m = \frac{(2 - 1)}{1} = 1$
#     + $y = mx + b, 1 = 1 * 1 + b, b = 0$
# + 6. h = 0.5
#     + $f(a+h) = 1.25$
#     + $m = \frac{(1.25 - 1)}{0.5} = 0.5$
#     + $y = mx + b, 1 = 1 * 0.5 + b, b = 0.5$

# %%
x = np.linspace(-10, 10, 100)
y = ((x - 1) ** 2) + 1
x1 =  np.linspace(-10, 10, 100)
y1 =  (2 * x) - 1
plt.plot(x,y)
plt.plot(x1,y1)
plt.title('h = 2')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-3, 6)
plt.ylim(-2, 10)
plt.legend(['(x-1)^2 + 1', 'y = 2x -1'])
plt.grid()
plt.show()

x = np.linspace(-10, 10, 100)
y = ((x - 1) ** 2) + 1
x1 =  np.linspace(-10, 10, 100)
y1 =  x1
plt.plot(x,y)
plt.plot(x1,y1)
plt.title('h = 1')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-1, 3)
plt.ylim(-2, 6)
plt.legend(['(x-1)^2 + 1', 'y = x'])
plt.grid()
plt.show()

x = np.linspace(-10, 10, 100)
y = ((x - 1) ** 2) + 1
x1 =  np.linspace(-10, 10, 100)
y1 =  (0.5 * x) + 0.5
plt.plot(x,y)
plt.plot(x1,y1)
plt.title('h = 0.5')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 3)
plt.ylim(-.5, 2.5)
plt.legend(['(x-1)^2 + 1', 'y = 0.5x +0.5'])
plt.grid()
plt.show()
